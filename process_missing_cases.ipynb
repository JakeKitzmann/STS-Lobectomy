# %%
from totalsegmentator.python_api import totalsegmentator

# %%
def run(path, out_path):
    totalsegmentator(path,
                 out_path,
                 roi_subset = [
                     "lung_lower_lobe_left",
                     "lung_lower_lobe_right",
                     "lung_middle_lobe_right",
                     "lung_upper_lobe_right",
                     "lung_upper_lobe_left"],
                device='gpu'
                )

# %%
run(
    r'Z:\SierenLab\DavidLee\CT_scans\O2\STSL0436\STSL0436_CT_CHEST_WO_CONTRAST__1499043345790752\Axial_Chest__1_0__Bf40\DICOM',
    r'missing_cases\0436'
)
# Out:
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Generating rough segmentation for cropping...
# Converting dicom to nifti...
#   found image with shape (512, 512, 359)
# Resampling...
#   Resampled in 0.10s
# Predicting...
# 100%|██████████| 4/4 [00:02<00:00,  1.44it/s]
# ...
#   Predicted in 41.17s
# Resampling...
#   Resampled in 1.59s
# Converting dicom to nifti...
#   found image with shape (512, 512, 359)
#   cropping from (512, 512, 359) to (393, 293, 301)
# Resampling...
#   Resampled in 1.54s
# Predicting part 1 of 1 ...
# 100%|██████████| 12/12 [00:57<00:00,  4.80s/it]
# ...
#   Predicted in 79.88s
# Resampling...
#   Resampled in 0.90s
# Saving segmentations...
#   Saved in 31.12s

# %%
run(
    r'Z:\SierenLab\DavidLee\CT_scans\O2\STSL0439\STSL0439_EXTERNAL_CT_CHEST_STORE_ONLY_2303571128203036\CHEST_W_O__3_0__I31f__2\DICOM',
    r'missing_cases\0439'
)
# Out:
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Generating rough segmentation for cropping...
# Converting dicom to nifti...
#   found image with shape (512, 512, 92)
# Resampling...
#   Resampled in 0.05s
# Predicting...
# 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]
# ...
#   Predicted in 21.78s
# Resampling...
#   Resampled in 0.38s
# Converting dicom to nifti...
#   found image with shape (512, 512, 92)
#   cropping from (512, 512, 92) to (468, 376, 86)
# Resampling...
#   Resampled in 0.64s
# Predicting part 1 of 1 ...
# 100%|██████████| 8/8 [00:36<00:00,  4.52s/it]
# ...
#   Predicted in 58.81s
# Resampling...
#   Resampled in 0.44s
# Saving segmentations...
#   Saved in 15.51s

# %%
run(
    r'Z:\SierenLab\DavidLee\altered_scans\0417_resampled',
    r'missing_cases\0417'
)
# Out:
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Generating rough segmentation for cropping...
# Converting dicom to nifti...
#   found image with shape (512, 512, 412)
# Resampling...
#   Resampled in 0.10s
# Predicting...
# 100%|██████████| 2/2 [00:01<00:00,  1.44it/s]
# ...
#   Predicted in 22.00s
# Resampling...
#   Resampled in 1.77s
# Converting dicom to nifti...
#   found image with shape (512, 512, 412)
#   cropping from (512, 512, 412) to (452, 345, 193)
# Resampling...
#   Resampled in 1.06s
# Predicting part 1 of 1 ...
# 100%|██████████| 8/8 [00:39<00:00,  4.96s/it]
# ...
#   Predicted in 61.10s
# Resampling...
#   Resampled in 0.77s
# Saving segmentations...
#   Saved in 27.52s

# %%
run(
    r'Z:\SierenLab\DavidLee\altered_scans\0197_acq_tfm_removed',
    r'missing_cases\0197'
)
# Out:
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Generating rough segmentation for cropping...
# Converting dicom to nifti...
#   found image with shape (512, 104, 512)
# Resampling...
#   Resampled in 0.06s
# Predicting...
# 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]
# ...
#   Predicted in 23.68s
# Resampling...
#   Resampled in 0.46s
# Converting dicom to nifti...
#   found image with shape (512, 104, 512)
#   cropping from (512, 104, 512) to (476, 88, 391)
# Resampling...
#   Resampled in 1.09s
# Predicting part 1 of 1 ...
# 100%|██████████| 12/12 [00:55<00:00,  4.59s/it]
# ...
#   Predicted in 77.36s
# Resampling...
#   Resampled in 0.62s
# Saving segmentations...
#   Saved in 15.99s
